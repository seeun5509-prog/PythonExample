# %%
f = open("demofile.txt")
print(f.read())
# Out:
# 가나다라마바사

# %%
f = open("D:\\myfiles\welcome.txt")
print(f.read)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# <>:1: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\김세은\AppData\Local\Temp\ipykernel_45600\1448209410.py:1: SyntaxWarning: invalid escape sequence '\w'
#   f = open("D:\\myfiles\welcome.txt")
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 f = open("D:\\myfiles\welcome.txt")
#       2 print(f.read)
#
# File c:\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:\\myfiles\\welcome.txt'

# %%
with open("demofile.txt") as f:
    print(f.read())
# Out:
# 가나다라마바사

# %%
f = open("demofile.txt")
print(f.readline())
f.close
# Out:
# 가나다라마바사
# <function TextIOWrapper.close()>

# %%
with open("demofile.txt") as f:
    print(f.read(5))
# Out:
# 가나다라마

# %%
with open("demofile.txt") as f:
    print(f.readline())
# Out:
# 가나다라마바사

# %%
with open("demofile.txt") as f:
    print(f.readline())
    print(f.readline())
# Out:
# 가나다라마바사

# %%
with open("demofile.txt") as f:
    for x in f:
        print(x)
# Out:
# 가나다라마바사

# %%
with open("demofile.txt", "a") as f:
    f.write("Now the file has more content!")
with open("demofile.txt") as f:
    print(f.read())
# Out:
# 가나다라마바사Now the file has more content!

# %%
with open("demofile.txt", "w") as f:
    f.write("woops! I have deleted the count!")
with open("demofile.txt") as f:
    print(f.read())
# Out:
# woops! I have deleted the count!

# %%
f = open("myfile.txt", "x")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 f = open("myfile.txt", "x")
#
# File c:\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileExistsError: [Errno 17] File exists: 'myfile.txt'

# %%
import os
if os.path.exists("demofile.txt"):
    os.remove("demofile.txt")
else:
    print("The file does not exist")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[29], line 3
#       1 import os
#       2 if os.path.exists("demofile.txt"):
# ----> 3     os.remove("demofile.txt")
#       4 else:
#       5     print("The file does not exist")
#
# PermissionError: [WinError 32] 다른 프로세스가 파일을 사용 중이기 때문에 프로세스가 액세스 할 수 없습니다: 'demofile.txt'

# %%
with open("demofile.txt", "w") as f:
    f.write("Woops! I have deleteed the content!")
with open("demofile.txt") as f:
    print(f.read())
# Out:
# Woops! I have deleteed the content!
