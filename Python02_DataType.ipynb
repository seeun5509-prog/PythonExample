# %%
price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# The price is 59 dollars

# %%
price = 59.0083
txt = f"The price is {price:.2f} dollars"
print(txt)
# Out:
# The price is 59.01 dollars

# %%
txt = f"The price is {20 * 59} dollars"
print(txt)
# Out:
# The price is 1180 dollars

# %%
a = 200
b = 33
if b > a:
    print("b is greater than a ")
else:
    print("b is nor greater than a ")
# Out:
# b is nor greater than a

# %%
print(bool("Hello"))
print(bool(15))
# Out:
# True
# True

# %%
x = "Hello"
y = 1
print(bool(x))
print(bool(y))
# Out:
# True
# True

# %%
sum1 = 100 + 50
sum2 = sum1 + 250
sum3 = sum2 + sum2
print(sum1)
print(sum2)
print(sum3)
# Out:
# 150
# 400
# 800

# %%
x = 15
y = 4
print(x + y)
print(x - y)
print(x * y)
print(x / y)
print(x % y)
print(x ** y)
print(x // y)
# Out:
# 19
# 11
# 60
# 3.75
# 3
# 50625
# 3

# %%
numbers = [1, 2, 3, 4, 5]
count = len(numbers)
if count > 3:
    print(f"List has {count} elements")
          
if (count := len(numbers)) > 3:
    print(f"List has {count} elements")
# Out:
# List has 5 elements
# List has 5 elements

# %%
x = ["apple", "banana"]
y = ["apple", "banana"]
z = x
print(x is z)
print(x is y)
print(x == y)
# Out:
# True
# False
# True

# %%
fruits = ["apple", "banana", "cherry"]
print("banana" in fruits)
# Out:
# True

# %%
text = "Hello World"
print("H" in text)
print("hello" in text)
print("z" not in text)
# Out:
# True
# False
# True

# %%
print(6 & 3)
print(6 | 3)
print(6 ^ 3)
# Out:
# 2
# 7
# 5
